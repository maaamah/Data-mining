# %%
import pandas as pd

# %%
df=pd.read_csv('kstudentbiodata_csv.csv')

# %%
df
# Out:
#            RegNumb      surname    mname  lastname  \
# 0         1.21E+11         BADA      NaN    Busola
# 1         2.81E+11         UGWU  Vincent  Nnabuike
# 2      30717102447  ELIAS-MOMOH      NaN     Mercy
# 3      21117084540    ABDULLAHI      NaN     Aliyu
# 4      80318204100        AKAWE    Felix     Amaru
# ...            ...          ...      ...       ...
# 27153          NaN          NaN      NaN       NaN
# 27154          NaN          NaN      NaN       NaN
# 27155          NaN          NaN      NaN       NaN
# 27156            0          100      NaN       NaN
# 27157   75443315FI       UNAGHA      NaN       NaN
#
#                                           email StateOfOrigin  LGA   Sex  \
# 0            bada.busola2019@st.uniabuja.edu.ng           NaN  NaN     F
# 1          ugwu.nnabuike2019@st.uniabuja.edu.ng         Enugu  NaN     M
# 2      elias-momoh.mercy2019@st.uniabuja.edu.ng          Kogi  NaN     F
# ...

# %%
import pandas as pd

# %%
df.head()
# Out:
#        RegNumb      surname    mname  lastname  \
# 0     1.21E+11         BADA      NaN    Busola
# 1     2.81E+11         UGWU  Vincent  Nnabuike
# 2  30717102447  ELIAS-MOMOH      NaN     Mercy
# 3  21117084540    ABDULLAHI      NaN     Aliyu
# 4  80318204100        AKAWE    Felix     Amaru
#
#                                       email StateOfOrigin  LGA Sex  \
# 0        bada.busola2019@st.uniabuja.edu.ng           NaN  NaN   F
# 1      ugwu.nnabuike2019@st.uniabuja.edu.ng         Enugu  NaN   M
# 2  elias-momoh.mercy2019@st.uniabuja.edu.ng          Kogi  NaN   F
# 3    abdullahi.aliyu2019@st.uniabuja.edu.ng        Sokoto  NaN   M
# 4        akawe.amaru2019@st.uniabuja.edu.ng         Delta  NaN   M
#
#                               faculty  \
# 0   Faculty Of Basic Medical Sciences
# 1   Faculty Of Basic Medical Sciences
# 2                Faculty Of Education
# 3      Faculty Of Management Sciences
# 4      Faculty Of Management Sciences
#
# ...

# %%
df.dtypes
# Out:
# RegNumb           object
# surname           object
# mname             object
# lastname          object
# email             object
# StateOfOrigin     object
# LGA               object
# Sex               object
# faculty           object
# dept              object
# Course            object
# duration          object
# Tel_no           float64
# level             object
# admode            object
# RefNumb           object
# sn                 int64
# dtype: object

# %%
df.tail()
# Out:
#           RegNumb surname mname lastname email StateOfOrigin  LGA   Sex  \
# 27153         NaN     NaN   NaN      NaN   NaN           NaN  NaN   NaN
# 27154         NaN     NaN   NaN      NaN   NaN           NaN  NaN   NaN
# 27155         NaN     NaN   NaN      NaN   NaN           NaN  NaN   NaN
# 27156           0     100   NaN      NaN   NaN           NaN  NaN  6619
# 27157  75443315FI  UNAGHA   NaN      NaN   NaN           NaN  NaN   NaN
#
#       faculty dept Course duration  Tel_no level admode   RefNumb    sn
# 27153     NaN  NaN    NaN      NaN     0.0   NaN    NaN  17283022  5954
# 27154     NaN  NaN    NaN      NaN     0.0   NaN    NaN  17283022  5955
# 27155     NaN  NaN    NaN      NaN     0.0   NaN    NaN       NaN     0
# 27156     NaN  NaN    NaN      NaN     0.0   NaN    NaN       NaN     0
# 27157     NaN  NaN    NaN      NaN     0.0   NaN    NaN       NaN     0

# %%
df.shape
# Out:
# (27158, 17)

# %%
pd.set_option('display.max_columns',17)

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [RegNumb, surname, mname, lastname, email, StateOfOrigin, LGA, Sex, faculty, dept, Course, duration, Tel_no, level, admode, RefNumb, sn]
# Index: []

# %%
df.dropna(axis='index', how='any')
# Out:
# Empty DataFrame
# Columns: [RegNumb, surname, mname, lastname, email, StateOfOrigin, LGA, Sex, faculty, dept, Course, duration, Tel_no, level, admode, RefNumb, sn]
# Index: []

# %%
import numpy as np

# %%
 df [df.isnull ().any (axis=1)]
# Out:
#            RegNumb      surname    mname  lastname  \
# 0         1.21E+11         BADA      NaN    Busola
# 1         2.81E+11         UGWU  Vincent  Nnabuike
# 2      30717102447  ELIAS-MOMOH      NaN     Mercy
# 3      21117084540    ABDULLAHI      NaN     Aliyu
# 4      80318204100        AKAWE    Felix     Amaru
# ...            ...          ...      ...       ...
# 27153          NaN          NaN      NaN       NaN
# 27154          NaN          NaN      NaN       NaN
# 27155          NaN          NaN      NaN       NaN
# 27156            0          100      NaN       NaN
# 27157   75443315FI       UNAGHA      NaN       NaN
#
#                                           email StateOfOrigin  LGA   Sex  \
# 0            bada.busola2019@st.uniabuja.edu.ng           NaN  NaN     F
# 1          ugwu.nnabuike2019@st.uniabuja.edu.ng         Enugu  NaN     M
# 2      elias-momoh.mercy2019@st.uniabuja.edu.ng          Kogi  NaN     F
# ...

# %%
df ['Sex'].value_counts ()
# Out:
# M         13809
# F         11803
# M            76
# F            25
# M.            2
# C             2
# N             1
# Female        1
# FEMALE        1
# 6619          1
# Name: Sex, dtype: int64

# %%
cleanup_sex={"sex":{"m":1, "f":3}}

# %%
df ['level'].value_counts ()
# Out:
# 100          11189
# 200LEVELS      101
# 200Levels       55
# 100Levels       36
# 100LEVEL        30
# 100LEVELS       16
# 200              3
# Name: level, dtype: int64

# %%
cleanup_level={"level":{"100":1,"200LEVELS":4,"0":4,"200":4, "200LEVELS":4}}

# %%
df.replace(cleanup_level,inplace= True)

# %%
cleanup_admode={"admode": {"UTME":10,"DE":20}}

# %%
df.replace(cleanup_admode,inplace= True)

# %%
df.head()
# Out:
#        RegNumb      surname    mname  lastname  \
# 0     1.21E+11         BADA      NaN    Busola
# 1     2.81E+11         UGWU  Vincent  Nnabuike
# 2  30717102447  ELIAS-MOMOH      NaN     Mercy
# 3  21117084540    ABDULLAHI      NaN     Aliyu
# 4  80318204100        AKAWE    Felix     Amaru
#
#                                       email StateOfOrigin  LGA Sex  \
# 0        bada.busola2019@st.uniabuja.edu.ng           NaN  NaN   F
# 1      ugwu.nnabuike2019@st.uniabuja.edu.ng         Enugu  NaN   M
# 2  elias-momoh.mercy2019@st.uniabuja.edu.ng          Kogi  NaN   F
# 3    abdullahi.aliyu2019@st.uniabuja.edu.ng        Sokoto  NaN   M
# 4        akawe.amaru2019@st.uniabuja.edu.ng         Delta  NaN   M
#
#                               faculty  \
# 0   Faculty Of Basic Medical Sciences
# 1   Faculty Of Basic Medical Sciences
# 2                Faculty Of Education
# 3      Faculty Of Management Sciences
# 4      Faculty Of Management Sciences
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#        RegNumb      surname    mname  lastname  \
# 0     1.21E+11         BADA      NaN    Busola
# 1     2.81E+11         UGWU  Vincent  Nnabuike
# 2  30717102447  ELIAS-MOMOH      NaN     Mercy
# 3  21117084540    ABDULLAHI      NaN     Aliyu
# 4  80318204100        AKAWE    Felix     Amaru
#
#                                       email StateOfOrigin  LGA Sex  \
# 0        bada.busola2019@st.uniabuja.edu.ng           NaN  NaN   F
# 1      ugwu.nnabuike2019@st.uniabuja.edu.ng         Enugu  NaN   M
# 2  elias-momoh.mercy2019@st.uniabuja.edu.ng          Kogi  NaN   F
# 3    abdullahi.aliyu2019@st.uniabuja.edu.ng        Sokoto  NaN   M
# 4        akawe.amaru2019@st.uniabuja.edu.ng         Delta  NaN   M
#
#                               faculty  \
# 0   Faculty Of Basic Medical Sciences
# 1   Faculty Of Basic Medical Sciences
# 2                Faculty Of Education
# 3      Faculty Of Management Sciences
# 4      Faculty Of Management Sciences
#
# ...

# %%
# fig, ax = plt.subplots()

# %%
from mpl_toolkits.mplot3d  import Axes3D

# %%
labels=['f','m']

# %%
colors=['red','blue']

# %%
patches,text =plt.pie(colors=colors, shadow=False, strangle=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16628/3950364292.py in <module>
# ----> 1 patches,text =plt.pie(colors=colors, shadow=False)
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
plt.legend(patches,labels,loc="best")

# %%
plt.title("STUDENTS GENDER PERCENTAGE")

# %%
plt.axis('equal')

# %%
plt.tight_layout()

# %%
plt.show

# %%
labels=['Faculty of Management Sciences' , 'Faculty of Agriculture' ,'Faculty of Sciences' , 'Faculty of Arts' , 'Faculty of Social Science' , 'Faculty of Engineering']

# %%
colors=['green','gold' 'purple','lightskyblue' 'red','blue']

# %%
patches,text =plt.pie(colors=colors, shadow=False,starangle=100)

# %%
plt.legend(patches,labels,loc="best")

# %%
plt.axis('equal')

# %%
plt.title("STUDENTS PERCENTAGE PER FACULTY")

# %%
plt.tight_layout()

# %%
plt.show

# %%
labels=[ 'BASIC MEDICAL SCIENCES' ,'Faculty of Management Sciences' , 'Faculty of Agriculture' ,'Faculty of Sciences' , 'Faculty of Arts' , 'Faculty of Social Science' , 'Faculty of Engineering']

# %%
colors=['black','green','gold' 'purple','lightskyblue' 'red','blue']

# %%
text =plt.pie(colors=colors, shadow=False,starangle=200)

# %%
plt.legend(patches,labels,loc="best")

# %%
plt.title("STUDENTS PERCENTAGE PER FACULTY")

# %%
plt.axis('equal')

# %%
plt.tight_layout()

# %%
plt.show

# %%
import seaborn as sns

# %%
#a simple plot using seaborn showing the count plot of faculty againsts sex
